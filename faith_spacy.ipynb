# %%
import pandas as pd
import re

# scraping modules
from requests import get
from bs4 import BeautifulSoup

import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import spacy

import os
import acquire
import prepare

# %% [markdown]
# # Acquire df Using Scraping Function

# %%
#acquire.scrape_github_data()

# %% [markdown]
# ## Write Scraped Data to json file

# %%
df = pd.read_json('data.json')

# %%
df.readme_contents[0]
# Out:
# "![freeCodeCamp.org Social Banner](https://s3.amazonaws.com/freecodecamp/wide-social-banner.png)\n\n[![Pull Requests Welcome](https://img.shields.io/badge/PRs-welcome-brightgreen.svg?style=flat)](http://makeapullrequest.com)\n[![first-timers-only Friendly](https://img.shields.io/badge/first--timers--only-friendly-blue.svg)](http://www.firsttimersonly.com/)\n[![Open Source Helpers](https://www.codetriage.com/freecodecamp/freecodecamp/badges/users.svg)](https://www.codetriage.com/freecodecamp/freecodecamp)\n[![Setup Automated](https://img.shields.io/badge/setup-automated-blue?logo=gitpod)](https://gitpod.io/from-referrer/)\n\n## freeCodeCamp.org's open-source codebase and curriculum\n\n[freeCodeCamp.org](https://www.freecodecamp.org) is a friendly community where you can learn to code for free. It is run by a [donor-supported 501(c)(3) nonprofit](https://donate.freecodecamp.org) to help  millions of busy adults transition into tech. Our community has already helped more than 10,000 people get their first developer job.\n\nOur full-stack web development curriculum is completely free and self-paced. We have thousands of interactive coding challenges to help you expand your skills.\n\n## Table of Contents\n\n* [Certifications](#certifications)\n* [The Learning Platform](#the-learning-platform)\n* [Reporting Bugs and Issues](#reporting-bugs-and-issues)\n* [Reporting Security Issues](#reporting-security-issues)\n* [Contributing](#contributing)\n* [Platform, Build and Deployment Status](#platform-build-and-deployment-status)\n* [License](#license)\n\n\n### Certifications\n\nfreeCodeCamp.org offers several free developer certifications. Each of these certifications involves building 5 required web app projects, along with hundreds of optional coding challenges to help you prepare for those projects. We estimate that each certification will take a beginning programmer around 300 hours to earn.\n\nEach of these 30 projects in the freeCodeCamp.org curriculum has its own agile user stories and automated tests. These help you build up your project incrementally and ensure you've fulfilled all the user stories before you submit it.\n\nYou can pull in these test suites through [freeCodeCamp's CDN](https://cdn.freecodecamp.org/testable-projects-fcc/v1/bundle.js). This means you can build these projects on websites like CodePen and Glitch - or even on your local computer's development environment.\n\nOnce you’ve earned a certification, you will always have it. You will always be able to link to it from your LinkedIn or résumé. And when your prospective employers or freelance clients click that link, they’ll see a verified certification specific to you.\n\nThe one exception to this is if we discover violations of our [Academic Honesty Policy](https://www.freecodecamp.org/academic-honesty). When we catch people unambiguously plagiarizing (submitting other people's code or projects as their own without citation), we do what all rigorous institutions of learning should do - we revoke their certifications and ban those people.\n\nHere are our six core certifications:\n\n#### 1. Responsive Web Design Certification\n\n- [Basic HTML and HTML5](https://learn.freecodecamp.org/responsive-web-design/basic-html-and-html5)\n- [Basic CSS](https://learn.freecodecamp.org/responsive-web-design/basic-css)\n- [Applied Visual Design](https://learn.freecodecamp.org/responsive-web-design/applied-visual-design)\n- [Applied Accessibility](https://learn.freecodecamp.org/responsive-web-design/applied-accessibility)\n- [Responsive Web Design Principles](https://learn.freecodecamp.org/responsive-web-design/responsive-web-design-principles)\n- [CSS Flexbox](https://learn.freecodecamp.org/responsive-web-design/css-flexbox)\n- [CSS Grid](https://learn.freecodecamp.org/responsive-web-design/css-grid)\n  <br />\n  <br />\n  **Projects**: Tribute Page, Survey Form, Product Landing Page, Technical Documentation Page, Personal Portfolio Webpage\n\n#### 2. JavaScript Algorithms and ...

# %% [markdown]
# # Load Spacy NLP Model

# %%
# load spacy library

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Create Doc Object

# %%
doc = nlp(u'Tesla is looking at buying U.S. startup for $6 million')

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Tesla PROPN nsubj
# is VERB aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S. PROPN compound
# startup NOUN dobj
# for ADP prep
# $ SYM quantmod
# 6 NUM compound
# million NUM pobj

# %% [markdown]
# ## Create Pipeline

# %%
nlp.pipeline
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger at 0x1a271928d0>),
#  ('parser', <spacy.pipeline.pipes.DependencyParser at 0x1a28a9bc48>),
#  ('ner', <spacy.pipeline.pipes.EntityRecognizer at 0x1a28a9bca8>)]

# %%
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %% [markdown]
# ### Check out on one Repo's README from json file

# %%
doc = nlp(u"![freeCodeCamp.org Social Banner](https://s3.amazonaws.com/freecodecamp/wide-social-banner.png)\n\n[![Pull Requests Welcome](https://img.shields.io/badge/PRs-welcome-brightgreen.svg?style=flat)](http://makeapullrequest.com)\n[![first-timers-only Friendly](https://img.shields.io/badge/first--timers--only-friendly-blue.svg)](http://www.firsttimersonly.com/)\n[![Open Source Helpers](https://www.codetriage.com/freecodecamp/freecodecamp/badges/users.svg)](https://www.codetriage.com/freecodecamp/freecodecamp)\n[![Setup Automated](https://img.shields.io/badge/setup-automated-blue?logo=gitpod)](https://gitpod.io/from-referrer/)\n\n## freeCodeCamp.org's open-source codebase and curriculum\n\n[freeCodeCamp.org](https://www.freecodecamp.org) is a friendly community where you can learn to code for free. It is run by a [donor-supported 501(c)(3) nonprofit](https://donate.freecodecamp.org) to help  millions of busy adults transition into tech. Our community has already helped more than 10,000 people get their first developer job.\n\nOur full-stack web development curriculum is completely free and self-paced. We have thousands of interactive coding challenges to help you expand your skills.\n\n## Table of Contents\n\n* [Certifications](#certifications)\n* [The Learning Platform](#the-learning-platform)\n* [Reporting Bugs and Issues](#reporting-bugs-and-issues)\n* [Reporting Security Issues](#reporting-security-issues)\n* [Contributing](#contributing)\n* [Platform, Build and Deployment Status](#platform-build-and-deployment-status)\n* [License](#license)\n\n\n### Certifications\n\nfreeCodeCamp.org offers several free developer certifications. Each of these certifications involves building 5 required web app projects, along with hundreds of optional coding challenges to help you prepare for those projects. We estimate that each certification will take a beginning programmer around 300 hours to earn.\n\nEach of these 30 projects in the freeCodeCamp.org curriculum has its own agile user stories and automated tests. These help you build up your project incrementally and ensure you've fulfilled all the user stories before you submit it.\n\nYou can pull in these test suites through [freeCodeCamp's CDN](https://cdn.freecodecamp.org/testable-projects-fcc/v1/bundle.js). This means you can build these projects on websites like CodePen and Glitch - or even on your local computer's development environment.\n\nOnce you’ve earned a certification, you will always have it. You will always be able to link to it from your LinkedIn or résumé. And when your prospective employers or freelance clients click that link, they’ll see a verified certification specific to you.\n\nThe one exception to this is if we discover violations of our [Academic Honesty Policy](https://www.freecodecamp.org/academic-honesty). When we catch people unambiguously plagiarizing (submitting other people's code or projects as their own without citation), we do what all rigorous institutions of learning should do - we revoke their certifications and ban those people.\n\nHere are our six core certifications:\n\n#### 1. Responsive Web Design Certification\n\n- [Basic HTML and HTML5](https://learn.freecodecamp.org/responsive-web-design/basic-html-and-html5)\n- [Basic CSS](https://learn.freecodecamp.org/responsive-web-design/basic-css)\n- [Applied Visual Design](https://learn.freecodecamp.org/responsive-web-design/applied-visual-design)\n- [Applied Accessibility](https://learn.freecodecamp.org/responsive-web-design/applied-accessibility)\n- [Responsive Web Design Principles](https://learn.freecodecamp.org/responsive-web-design/responsive-web-design-principles)\n- [CSS Flexbox](https://learn.freecodecamp.org/responsive-web-design/css-flexbox)\n- [CSS Grid](https://learn.freecodecamp.org/responsive-web-design/css-grid)\n  <br />\n  <br />\n  **Projects**: Tribute Page, Survey Form, Product Landing Page, Technical Documentation Page, Personal Portfolio Webpage\n\n#### 2. JavaScript Algorithms and Data Structures Certification\n\n- [Basic JavaScript](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/basic-javascript)\n- [ES6](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/es6)\n- [Regular Expressions](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/regular-expressions)\n- [Debugging](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/debugging)\n- [Basic Data Structures](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/basic-data-structures)\n- [Algorithm Scripting](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/basic-algorithm-scripting)\n- [Object-Oriented Programming](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/object-oriented-programming)\n- [Functional Programming](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/functional-programming)\n- [Intermediate Algorithm Scripting](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/intermediate-algorithm-scripting)\n  <br />\n  <br />\n  **Projects**: Palindrome Checker, Roman Numeral Converter, Caesar's Cipher, Telephone Number Validator, Cash Register\n\n#### 3. Front End Libraries Certification\n\n- [Bootstrap](https://learn.freecodecamp.org/front-end-libraries/bootstrap)\n- [jQuery](https://learn.freecodecamp.org/front-end-libraries/jquery)\n- [Sass](https://learn.freecodecamp.org/front-end-libraries/sass)\n- [React](https://learn.freecodecamp.org/front-end-libraries/react)\n- [Redux](https://learn.freecodecamp.org/front-end-libraries/redux)\n- [React and Redux](https://learn.freecodecamp.org/front-end-libraries/react-and-redux)\n  <br />\n  <br />\n  **Projects**: Random Quote Machine, Markdown Previewer, Drum Machine, JavaScript Calculator, Pomodoro Clock\n\n#### 4. Data Visualization Certification\n\n- [Data Visualization with D3](https://learn.freecodecamp.org/data-visualization/data-visualization-with-d3)\n- [JSON APIs and Ajax](https://learn.freecodecamp.org/data-visualization/json-apis-and-ajax)\n  <br />\n  <br />\n  **Projects**: Bar Chart, Scatterplot Graph, Heat Map, Choropleth Map, Treemap Diagram\n\n#### 5. APIs and Microservices Certification\n\n- [Managing Packages with Npm](https://learn.freecodecamp.org/apis-and-microservices/managing-packages-with-npm)\n- [Basic Node and Express](https://learn.freecodecamp.org/apis-and-microservices/basic-node-and-express)\n- [MongoDB and Mongoose](https://learn.freecodecamp.org/apis-and-microservices/mongodb-and-mongoose)\n  <br />\n  <br />\n  **Projects**: Timestamp Microservice, Request Header Parser, URL Shortener, Exercise Tracker, File Metadata Microservice\n\n#### 6. Information Security and Quality Assurance Certification\n\n- [Information Security with HelmetJS](https://learn.freecodecamp.org/information-security-and-quality-assurance/information-security-with-helmetjs)\n- [Quality Assurance and Testing with Chai](https://learn.freecodecamp.org/information-security-and-quality-assurance/quality-assurance-and-testing-with-chai)\n- [Advanced Node and Express](https://learn.freecodecamp.org/information-security-and-quality-assurance/advanced-node-and-express)\n  <br />\n  <br />\n  **Projects**: Metric-Imperial Converter, Issue Tracker, Personal Library, Stock Price Checker, Anonymous Message Board\n\n#### Full Stack Development Certification\n\nOnce you have earned all 6 of these certifications, you'll be able to claim your freeCodeCamp.org Full Stack Development Certification. This final distinction signifies that you’ve completed around 1,800 hours of coding with a wide range of web development tools.\n\n#### Legacy Certifications\n\nWe also have 3 legacy certifications from our 2015 curriculum, which are still available. All of the required projects for these legacy certifications will remain available on freeCodeCamp.org.\n\n- Legacy Front End Development Certification\n- Legacy Data Visualization Certification\n- Legacy Back End Development Certification\n\n### The Learning Platform\n\nThis code is running live at [freeCodeCamp.org](https://www.freecodecamp.org).\n\nOur community also has:\n\n- A [forum](https://www.freecodecamp.org/forum) where you can usually get programming help or project feedback within hours.\n- A [YouTube channel](https://youtube.com/freecodecamp) with free courses on Python, SQL, Android, and a wide variety of other technologies.\n- A [podcast](https://podcast.freecodecamp.org/) with technology insights and inspiring stories from developers.\n- A [Developer News](https://www.freecodecamp.org/news) publication, a free, open source, no-ads place to cross-post your blog articles.\n\n> ### [Join our community here](https://www.freecodecamp.org/signin).\n\n### Reporting Bugs and Issues\nIf you think you've found a bug, first read the [how to report a bug](https://www.freecodecamp.org/forum/t/how-to-report-a-bug/19543) article and follow its instructions.\n\nIf you're confident it's a new bug and have confirmed that someone else is facing the same issue, go ahead and create a new GitHub issue. Be sure to include as much information as possible so we can reproduce the bug.\n\n### Reporting Security Issues\n\nIf you think you have found a vulnerability, please report responsibly. Don't create GitHub issues for security issues. Instead, please send an email to `security@freecodecamp.org` and we'll look into it immediately.\n\n### Contributing\n\n> ### [Please follow these steps to contribute.](CONTRIBUTING.md)\n\n### Platform, Build and Deployment Status\n\nThe general platform status for all our applications is available at [`status.freecodecamp.org`](https://status.freecodecamp.org). The build and deployment status for the code is available in [our DevOps Guide](/docs/devops.md).\n\n### License\n\nCopyright © 2019 freeCodeCamp.org\n\nThe content of this repository is bound by the following licenses:\n\n- The computer software is licensed under the [BSD-3-Clause](LICENSE.md) license.\n- The learning resources in the [`/curriculum`](/curriculum) directory including their subdirectories thereon are licensed under the [CC-BY-SA-4.0](/curriculum/LICENSE.md) license.\n")

# %%
for token in doc:
    print(token.text)
# Out:
# !
# [
# freeCodeCamp.org
# Social
# Banner](https://s3.amazonaws.com
# /
# freecodecamp
# /
# wide
# -
# social
# -
# banner.png
# )
#
#
#
# [
# !
# [
# Pull
# Requests
# Welcome](https://img.shields.io
# /
# badge
# /
# PRs
# -
# welcome
# -
# brightgreen.svg?style
# =
# flat)](http://makeapullrequest.com
# )
#
#
# [
# !
# [
# first
# -
# timers
# -
# only
# Friendly](https://img.shields.io
# /
# badge
# /
# first
# --
# timers
# --
# only
# -
# friendly
# -
# blue.svg)](http://www.firsttimersonly.com/
# )
#
#
# [
# !
# [
# Open
# Source
# Helpers](https://www.codetriage.com
# /
# freecodecamp
# /
# freecodecamp
# /
# badges
# /
# users.svg)](https://www.codetriage.com
# /
# freecodecamp
# /
# freecodecamp
# )
#
#
# [
# !
# [
# Setup
# Automated](https://img.shields.io
# /
# badge
# /
# setup
# -
# automated
# -
# blue?logo
# =
# gitpod)](https://gitpod.io
# /
# from
# -
# referrer/
# )
#
#
#
# #
# #
# freeCodeCamp.org
# 's
# open
# -
# source
# codebase
# and
# curriculum
#
#
#
# [
# freeCodeCamp.org](https://www.freecodecamp.org
# )
# is
# a
# friendly
# community
# where
# you
# can
# learn
# to
# code
# for
# free
# .
# It
# is
# run
# by
# a
# [
# donor
# -
# supported
# 501(c)(3
# )
# nonprofit](https://donate.freecodecamp.org
# )
# to
# help
#
# millions
# of
# busy
# adults
# transition
# into
# tech
# .
# Our
# community
# has
# already
# helped
# more
# than
# 10,000
# people
# get
# their
# first
# developer
# job
# .
#
#
#
# Our
# full
# -
# stack
# web
# development
# curriculum
# is
# completely
# free
# and
# self
# -
# paced
# .
# We
# have
# thousands
# of
# interactive
# coding
# challenges
# to
# help
# you
# expand
# your
# skills
# .
#
#
#
# #
# #
# Table
# of
# Contents
#
#
#
# *
# [
# Certifications](#certifications
# )
#
#
# *
# [
# The
# Learning
# Platform](#the
# -
# learning
# -
# platform
# )
#
#
# *
# [
# Reporting
# Bugs
# and
# Issues](#reporting
# -
# bugs
# -
# and
# -
# issues
# )
#
#
# *
# [
# Reporting
# Security
# Issues](#reporting
# -
# security
# -
# issues
# )
#
#
# *
# [
# Contributing](#contributing
# )
#
#
# *
# [
# Platform
# ,
# Build
# and
# Deployment
# Status](#platform
# -
# build
# -
# and
# -
# deployment
# -
# status
# )
#
#
# *
# [
# License](#license
# )
#
#
#
#
# #
# #
# #
# Certifications
#
#
#
# freeCodeCamp.org
# offers
# several
# free
# developer
# certifications
# .
# Each
# of
# these
# certifications
# involves
# building
# 5
# required
# web
# app
# projects
# ,
# along
# with
# hundreds
# of
# optional
# coding
# challenges
# to
# help
# you
# prepare
# for
# those
# projects
# .
# We
# estimate
# that
# each
# certification
# will
# take
# a
# beginning
# programmer
# around
# 300
# hours
# to
# earn
# .
#
#
#
# Each
# of
# these
# 30
# projects
# in
# the
# freeCodeCamp.org
# curriculum
# has
# its
# own
# agile
# user
# stories
# and
# automated
# tests
# .
# These
# help
# you
# build
# up
# your
# project
# incrementally
# and
# ensure
# you
# 've
# fulfilled
# all
# the
# user
# stories
# before
# you
# submit
# it
# .
#
#
#
# You
# can
# pull
# in
# these
# test
# suites
# through
# [
# freeCodeCamp
# 's
# CDN](https://cdn.freecodecamp.org
# /
# testable
# -
# projects
# -
# fcc
# /
# v1/bundle.js
# )
# .
# This
# means
# you
# can
# build
# these
# projects
# on
# websites
# like
# CodePen
# and
# Glitch
# -
# or
# even
# on
# your
# local
# computer
# 's
# development
# environment
# .
#
#
#
# Once
# you
# ’ve
# earned
# a
# certification
# ,
# you
# will
# always
# have
# it
# .
# You
# will
# always
# be
# able
# to
# link
# to
# it
# from
# your
# LinkedIn
# or
# résumé
# .
# And
# when
# your
# prospective
# employers
# or
# freelance
# clients
# click
# that
# link
# ,
# they
# ’ll
# see
# a
# verified
# certification
# specific
# to
# you
# .
#
#
#
# The
# one
# exception
# to
# this
# is
# if
# we
# discover
# violations
# of
# our
# [
# Academic
# Honesty
# Policy](https://www.freecodecamp.org
# /
# academic
# -
# honesty
# )
# .
# When
# we
# catch
# people
# unambiguously
# plagiarizing
# (
# submitting
# other
# people
# 's
# code
# or
# projects
# as
# their
# own
# without
# citation
# )
# ,
# we
# do
# what
# all
# rigorous
# institutions
# of
# learning
# should
# do
# -
# we
# revoke
# their
# certifications
# and
# ban
# those
# people
# .
#
#
#
# Here
# are
# our
# six
# core
# certifications
# :
#
#
#
# #
# #
# #
# #
# 1
# .
# Responsive
# Web
# Design
# Certification
#
#
#
# -
# [
# Basic
# HTML
# and
# HTML5](https://learn.freecodecamp.org
# /
# responsive
# -
# web
# -
# design
# /
# basic
# -
# html
# -
# and
# -
# html5
# )
#
#
# -
# [
# Basic
# CSS](https://learn.freecodecamp.org
# /
# responsive
# -
# web
# -
# design
# /
# basic
# -
# css
# )
#
#
# -
# [
# Applied
# Visual
# Design](https://learn.freecodecamp.org
# /
# responsive
# -
# web
# -
# design
# /
# applied
# -
# visual
# -
# design
# )
#
#
# -
# [
# Applied
# Accessibility](https://learn.freecodecamp.org
# /
# responsive
# -
# web
# -
# design
# /
# applied
# -
# accessibility
# )
#
#
# -
# [
# Responsive
# Web
# Design
# Principles](https://learn.freecodecamp.org
# /
# responsive
# -
# web
# -
# design
# /
# responsive
# -
# web
# -
# design
# -
# principles
# )
#
#
# -
# [
# CSS
# Flexbox](https://learn.freecodecamp.org
# /
# responsive
# -
# web
# -
# design
# /
# css
# -
# flexbox
# )
#
#
# -
# [
# CSS
# Grid](https://learn.freecodecamp.org
# /
# responsive
# -
# web
# -
# design
# /
# css
# -
# grid
# )
#
#
# <
# br
# /
# >
#
#
# <
# br
# /
# >
#
#
# *
# *
# Projects
# *
# *
# :
# Tribute
# Page
# ,
# Survey
# Form
# ,
# Product
# Landing
# Page
# ,
# Technical
# Documentation
# Page
# ,
# Personal
# Portfolio
# Webpage
#
#
#
# #
# #
# #
# #
# 2
# .
# JavaScript
# Algorithms
# and
# Data
# Structures
# Certification
#
#
#
# -
# [
# Basic
# JavaScript](https://learn.freecodecamp.org
# /
# javascript
# -
# algorithms
# -
# and
# -
# data
# -
# structures
# /
# basic
# -
# javascript
# )
#
#
# -
# [
# ES6](https://learn.freecodecamp.org
# /
# javascript
# -
# algorithms
# -
# and
# -
# data
# -
# structures
# /
# es6
# )
#
#
# -
# [
# Regular
# Expressions](https://learn.freecodecamp.org
# /
# javascript
# -
# algorithms
# -
# and
# -
# data
# -
# structures
# /
# regular
# -
# expressions
# )
#
#
# -
# [
# Debugging](https://learn.freecodecamp.org
# /
# javascript
# -
# algorithms
# -
# and
# -
# data
# -
# structures
# /
# debugging
# )
#
#
# -
# [
# Basic
# Data
# Structures](https://learn.freecodecamp.org
# /
# javascript
# -
# algorithms
# -
# and
# -
# data
# -
# structures
# /
# basic
# -
# data
# -
# structures
# )
#
#
# -
# [
# Algorithm
# Scripting](https://learn.freecodecamp.org
# /
# javascript
# -
# algorithms
# -
# and
# -
# data
# -
# structures
# /
# basic
# -
# algorithm
# -
# scripting
# )
#
#
# -
# [
# Object
# -
# Oriented
# Programming](https://learn.freecodecamp.org
# /
# javascript
# -
# algorithms
# -
# and
# -
# data
# -
# structures
# /
# object
# -
# oriented
# -
# programming
# )
#
#
# -
# [
# Functional
# Programming](https://learn.freecodecamp.org
# /
# javascript
# -
# algorithms
# -
# and
# -
# data
# -
# structures
# /
# functional
# -
# programming
# )
#
#
# -
# [
# Intermediate
# Algorithm
# Scripting](https://learn.freecodecamp.org
# /
# javascript
# -
# algorithms
# -
# and
# -
# data
# -
# structures
# /
# intermediate
# -
# algorithm
# -
# scripting
# )
#
#
# <
# br
# /
# >
#
#
# <
# br
# /
# >
#
#
# *
# *
# Projects
# *
# *
# :
# Palindrome
# Checker
# ,
# Roman
# Numeral
# Converter
# ,
# Caesar
# 's
# Cipher
# ,
# Telephone
# Number
# Validator
# ,
# Cash
# Register
#
#
#
# #
# #
# #
# #
# 3
# .
# Front
# End
# Libraries
# Certification
#
#
#
# -
# [
# Bootstrap](https://learn.freecodecamp.org
# /
# front
# -
# end
# -
# libraries
# /
# bootstrap
# )
#
#
# -
# [
# jQuery](https://learn.freecodecamp.org
# /
# front
# -
# end
# -
# libraries
# /
# jquery
# )
#
#
# -
# [
# Sass](https://learn.freecodecamp.org
# /
# front
# -
# end
# -
# libraries
# /
# sass
# )
#
#
# -
# [
# React](https://learn.freecodecamp.org
# /
# front
# -
# end
# -
# libraries
# /
# react
# )
#
#
# -
# [
# Redux](https://learn.freecodecamp.org
# /
# front
# -
# end
# -
# libraries
# /
# redux
# )
#
#
# -
# [
# React
# and
# Redux](https://learn.freecodecamp.org
# /
# front
# -
# end
# -
# libraries
# /
# react
# -
# and
# -
# redux
# )
#
#
# <
# br
# /
# >
#
#
# <
# br
# /
# >
#
#
# *
# *
# Projects
# *
# *
# :
# Random
# Quote
# Machine
# ,
# Markdown
# Previewer
# ,
# Drum
# Machine
# ,
# JavaScript
# Calculator
# ,
# Pomodoro
# Clock
#
#
#
# #
# #
# #
# #
# 4
# .
# Data
# Visualization
# Certification
#
#
#
# -
# [
# Data
# Visualization
# with
# D3](https://learn.freecodecamp.org
# /
# data
# -
# visualization
# /
# data
# -
# visualization
# -
# with
# -
# d3
# )
#
#
# -
# [
# JSON
# APIs
# and
# Ajax](https://learn.freecodecamp.org
# /
# data
# -
# visualization
# /
# json
# -
# apis
# -
# and
# -
# ajax
# )
#
#
# <
# br
# /
# >
#
#
# <
# br
# /
# >
#
#
# *
# *
# Projects
# *
# *
# :
# Bar
# Chart
# ,
# Scatterplot
# Graph
# ,
# Heat
# Map
# ,
# Choropleth
# Map
# ,
# Treemap
# Diagram
#
#
#
# #
# #
# #
# #
# 5
# .
# APIs
# and
# Microservices
# Certification
#
#
#
# -
# [
# Managing
# Packages
# with
# Npm](https://learn.freecodecamp.org
# /
# apis
# -
# and
# -
# microservices
# /
# managing
# -
# packages
# -
# with
# -
# npm
# )
#
#
# -
# [
# Basic
# Node
# and
# Express](https://learn.freecodecamp.org
# /
# apis
# -
# and
# -
# microservices
# /
# basic
# -
# node
# -
# and
# -
# express
# )
#
#
# -
# [
# MongoDB
# and
# Mongoose](https://learn.freecodecamp.org
# /
# apis
# -
# and
# -
# microservices
# /
# mongodb
# -
# and
# -
# mongoose
# )
#
#
# <
# br
# /
# >
#
#
# <
# br
# /
# >
#
#
# *
# *
# Projects
# *
# *
# :
# Timestamp
# Microservice
# ,
# Request
# Header
# Parser
# ,
# URL
# Shortener
# ,
# Exercise
# Tracker
# ,
# File
# Metadata
# Microservice
#
#
#
# #
# #
# #
# #
# 6
# .
# Information
# Security
# and
# Quality
# Assurance
# Certification
#
#
#
# -
# [
# Information
# Security
# with
# HelmetJS](https://learn.freecodecamp.org
# /
# information
# -
# security
# -
# and
# -
# quality
# -
# assurance
# /
# information
# -
# security
# -
# with
# -
# helmetjs
# )
#
#
# -
# [
# Quality
# Assurance
# and
# Testing
# with
# Chai](https://learn.freecodecamp.org
# /
# information
# -
# security
# -
# and
# -
# quality
# -
# assurance
# /
# quality
# -
# assurance
# -
# and
# -
# testing
# -
# with
# -
# chai
# )
#
#
# -
# [
# Advanced
# Node
# and
# Express](https://learn.freecodecamp.org
# /
# information
# -
# security
# -
# and
# -
# quality
# -
# assurance
# /
# advanced
# -
# node
# -
# and
# -
# express
# )
#
#
# <
# br
# /
# >
#
#
# <
# br
# /
# >
#
#
# *
# *
# Projects
# *
# *
# :
# Metric
# -
# Imperial
# Converter
# ,
# Issue
# Tracker
# ,
# Personal
# Library
# ,
# Stock
# Price
# Checker
# ,
# Anonymous
# Message
# Board
#
#
#
# #
# #
# #
# #
# Full
# Stack
# Development
# Certification
#
#
#
# Once
# you
# have
# earned
# all
# 6
# of
# these
# certifications
# ,
# you
# 'll
# be
# able
# to
# claim
# your
# freeCodeCamp.org
# Full
# Stack
# Development
# Certification
# .
# This
# final
# distinction
# signifies
# that
# you
# ’ve
# completed
# around
# 1,800
# hours
# of
# coding
# with
# a
# wide
# range
# of
# web
# development
# tools
# .
#
#
#
# #
# #
# #
# #
# Legacy
# Certifications
#
#
#
# We
# also
# have
# 3
# legacy
# certifications
# from
# our
# 2015
# curriculum
# ,
# which
# are
# still
# available
# .
# All
# of
# the
# required
# projects
# for
# these
# legacy
# certifications
# will
# remain
# available
# on
# freeCodeCamp.org
# .
#
#
#
# -
# Legacy
# Front
# End
# Development
# Certification
#
#
# -
# Legacy
# Data
# Visualization
# Certification
#
#
# -
# Legacy
# Back
# End
# Development
# Certification
#
#
#
# #
# #
# #
# The
# Learning
# Platform
#
#
#
# This
# code
# is
# running
# live
# at
# [
# freeCodeCamp.org](https://www.freecodecamp.org
# )
# .
#
#
#
# Our
# community
# also
# has
# :
#
#
#
# -
# A
# [
# forum](https://www.freecodecamp.org
# /
# forum
# )
# where
# you
# can
# usually
# get
# programming
# help
# or
# project
# feedback
# within
# hours
# .
#
#
# -
# A
# [
# YouTube
# channel](https://youtube.com
# /
# freecodecamp
# )
# with
# free
# courses
# on
# Python
# ,
# SQL
# ,
# Android
# ,
# and
# a
# wide
# variety
# of
# other
# technologies
# .
#
#
# -
# A
# [
# podcast](https://podcast.freecodecamp.org/
# )
# with
# technology
# insights
# and
# inspiring
# stories
# from
# developers
# .
#
#
# -
# A
# [
# Developer
# News](https://www.freecodecamp.org
# /
# news
# )
# publication
# ,
# a
# free
# ,
# open
# source
# ,
# no
# -
# ads
# place
# to
# cross
# -
# post
# your
# blog
# articles
# .
#
#
#
# >
# #
# #
# #
# [
# Join
# our
# community
# here](https://www.freecodecamp.org
# /
# signin
# )
# .
#
#
#
# #
# #
# #
# Reporting
# Bugs
# and
# Issues
#
#
# If
# you
# think
# you
# 've
# found
# a
# bug
# ,
# first
# read
# the
# [
# how
# to
# report
# a
# bug](https://www.freecodecamp.org
# /
# forum
# /
# t
# /
# how
# -
# to
# -
# report
# -
# a
# -
# bug/19543
# )
# article
# and
# follow
# its
# instructions
# .
#
#
#
# If
# you
# 're
# confident
# it
# 's
# a
# new
# bug
# and
# have
# confirmed
# that
# someone
# else
# is
# facing
# the
# same
# issue
# ,
# go
# ahead
# and
# create
# a
# new
# GitHub
# issue
# .
# Be
# sure
# to
# include
# as
# much
# information
# as
# possible
# so
# we
# can
# reproduce
# the
# bug
# .
#
#
#
# #
# #
# #
# Reporting
# Security
# Issues
#
#
#
# If
# you
# think
# you
# have
# found
# a
# vulnerability
# ,
# please
# report
# responsibly
# .
# Do
# n't
# create
# GitHub
# issues
# for
# security
# issues
# .
# Instead
# ,
# please
# send
# an
# email
# to
# `
# security@freecodecamp.org
# `
# and
# we
# 'll
# look
# into
# it
# immediately
# .
#
#
#
# #
# #
# #
# Contributing
#
#
#
# >
# #
# #
# #
# [
# Please
# follow
# these
# steps
# to
# contribute.](CONTRIBUTING.md
# )
#
#
#
# #
# #
# #
# Platform
# ,
# Build
# and
# Deployment
# Status
#
#
#
# The
# general
# platform
# status
# for
# all
# our
# applications
# is
# available
# at
# [
# `
# status.freecodecamp.org`](https://status.freecodecamp.org
# )
# .
# The
# build
# and
# deployment
# status
# for
# the
# code
# is
# available
# in
# [
# our
# DevOps
# Guide](/docs
# /
# devops.md
# )
# .
#
#
#
# #
# #
# #
# License
#
#
#
# Copyright
# ©
# 2019
# freeCodeCamp.org
#
#
#
# The
# content
# of
# this
# repository
# is
# bound
# by
# the
# following
# licenses
# :
#
#
#
# -
# The
# computer
# software
# is
# licensed
# under
# the
# [
# BSD-3-Clause](LICENSE.md
# )
# license
# .
#
#
# -
# The
# learning
# resources
# in
# the
# [
# `
# /curriculum`](/curriculum
# )
# directory
# including
# their
# subdirectories
# thereon
# are
# licensed
# under
# the
# [
# CC
# -
# BY
# -
# SA-4.0](/curriculum
# /
# LICENSE.md
# )
# license
# .

# %%
len(doc)
# Out:
# 1908

# %%
len(doc.vocab)
# Out:
# 1040

# %%
doc[109:1908]
# Out:
# freeCodeCamp.org](https://www.freecodecamp.org) is a friendly community where you can learn to code for free. It is run by a [donor-supported 501(c)(3) nonprofit](https://donate.freecodecamp.org) to help  millions of busy adults transition into tech. Our community has already helped more than 10,000 people get their first developer job.
#
# Our full-stack web development curriculum is completely free and self-paced. We have thousands of interactive coding challenges to help you expand your skills.
#
# ## Table of Contents
#
# * [Certifications](#certifications)
# * [The Learning Platform](#the-learning-platform)
# * [Reporting Bugs and Issues](#reporting-bugs-and-issues)
# * [Reporting Security Issues](#reporting-security-issues)
# * [Contributing](#contributing)
# * [Platform, Build and Deployment Status](#platform-build-and-deployment-status)
# * [License](#license)
#
#
# ### Certifications
#
# freeCodeCamp.org offers several free developer certifications. Each of these certifications involves building 5 required web app projects, along with hundreds of optional coding challenges to help you prepare for those projects. We estimate that each certification will take a beginning programmer around 300 hours to earn.
#
# Each of these 30 projects in the freeCodeCamp.org curriculum has its own agile user stories and automated tests. These help you build up your project incrementally and ensure you've fulfilled all the user stories before you submit it.
#
# You can pull in these test suites through [freeCodeCamp's CDN](https://cdn.freecodecamp.org/testable-projects-fcc/v1/bundle.js). This means you can build these projects on websites like CodePen and Glitch - or even on your local computer's development environment.
#
# Once you’ve earned a certification, you will always have it. You will always be able to link to it from your LinkedIn or résumé. And when your prospective employers or freelance clients click that link, they’ll see a verified certification specific to you.
#
# The one exception to this is if we discover violations of our [Academic Honesty Policy](https://www.freecodecamp.org/academic-honesty). When we catch people unambiguously plagiarizing (submitting other people's code or projects as their own without citation), we do what all rigorous institutions of learning should do - we revoke their certifications and ban those people.
#
# Here are our six core certifications:
#
# #### 1. Responsive Web Design Certification
#
# - [Basic HTML and HTML5](https://learn.freecodecamp.org/responsive-web-design/basic-html-and-html5)
# - [Basic CSS](https://learn.freecodecamp.org/responsive-web-design/basic-css)
# - [Applied Visual Design](https://learn.freecodecamp.org/responsive-web-design/applied-visual-design)
# - [Applied Accessibility](https://learn.freecodecamp.org/responsive-web-design/applied-accessibility)
# - [Responsive Web Design Principles](https://learn.freecodecamp.org/responsive-web-design/responsive-web-design-principles)
# - [CSS Flexbox](https://learn.freecodecamp.org/responsive-web-design/css-flexbox)
# - [CSS Grid](https://learn.freecodecamp.org/responsive-web-design/css-grid)
#   <br />
#   <br />
#   **Projects**: Tribute Page, Survey Form, Product Landing Page, Technical Documentation Page, Personal Portfolio Webpage
#
# #### 2. JavaScript Algorithms and Data Structures Certification
#
# - [Basic JavaScript](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/basic-javascript)
# - [ES6](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/es6)
# - [Regular Expressions](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/regular-expressions)
# - [Debugging](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/debugging)
# - [Basic Data Structures](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/basic-data-structures)
# - [Algorithm Scripting](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/basic-algorithm-scripting)
# - [Object-Oriented Programming](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/object-oriented-programming)
# - [Functional Programming](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/functional-programming)
# - [Intermediate Algorithm Scripting](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/intermediate-algorithm-scripting)
#   <br />
#   <br />
#   **Projects**: Palindrome Checker, Roman Numeral Converter, Caesar's Cipher, Telephone Number Validator, Cash Register
#
# #### 3. Front End Libraries Certification
#
# - [Bootstrap](https://learn.freecodecamp.org/front-end-libraries/bootstrap)
# - [jQuery](https://learn.freecodecamp.org/front-end-libraries/jquery)
# - [Sass](https://learn.freecodecamp.org/front-end-libraries/sass)
# - [React](https://learn.freecodecamp.org/front-end-libraries/react)
# - [Redux](https://learn.freecodecamp.org/front-end-libraries/redux)
# - [React and Redux](https://learn.freecodecamp.org/front-end-libraries/react-and-redux)
#   <br />
#   <br />
#   **Projects**: Random Quote Machine, Markdown Previewer, Drum Machine, JavaScript Calculator, Pomodoro Clock
#
# #### 4. Data Visualization Certification
#
# - [Data Visualization with D3](https://learn.freecodecamp.org/data-visualization/data-visualization-with-d3)
# - [JSON APIs and Ajax](https://learn.freecodecamp.org/data-visualization/json-apis-and-ajax)
#   <br />
#   <br />
#   **Projects**: Bar Chart, Scatterplot Graph, Heat Map, Choropleth Map, Treemap Diagram
#
# #### 5. APIs and Microservices Certification
#
# - [Managing Packages with Npm](https://learn.freecodecamp.org/apis-and-microservices/managing-packages-with-npm)
# - [Basic Node and Express](https://learn.freecodecamp.org/apis-and-microservices/basic-node-and-express)
# - [MongoDB and Mongoose](https://learn.freecodecamp.org/apis-and-microservices/mongodb-and-mongoose)
#   <br />
#   <br />
#   **Projects**: Timestamp Microservice, Request Header Parser, URL Shortener, Exercise Tracker, File Metadata Microservice
#
# #### 6. Information Security and Quality Assurance Certification
#
# - [Information Security with HelmetJS](https://learn.freecodecamp.org/information-security-and-quality-assurance/information-security-with-helmetjs)
# - [Quality Assurance and Testing with Chai](https://learn.freecodecamp.org/information-security-and-quality-assurance/quality-assurance-and-testing-with-chai)
# - [Advanced Node and Express](https://learn.freecodecamp.org/information-security-and-quality-assurance/advanced-node-and-express)
#   <br />
#   <br />
#   **Projects**: Metric-Imperial Converter, Issue Tracker, Personal Library, Stock Price Checker, Anonymous Message Board
#
# #### Full Stack Development Certification
#
# Once you have earned all 6 of these certifications, you'll be able to claim your freeCodeCamp.org Full Stack Development Certification. This final distinction signifies that you’ve completed around 1,800 hours of coding with a wide range of web development tools.
#
# #### Legacy Certifications
#
# We also have 3 legacy certifications from our 2015 curriculum, which are still available. All of the required projects for these legacy certifications will remain available on freeCodeCamp.org.
#
# - Legacy Front End Development Certification
# - Legacy Data Visualization Certification
# - Legacy Back End Development Certification
#
# ### The Learning Platform
#
# This code is running live at [freeCodeCamp.org](https://www.freecodecamp.org).
#
# Our community also has:
#
# - A [forum](https://www.freecodecamp.org/forum) where you can usually get programming help or project feedback within hours.
# - A [YouTube channel](https://youtube.com/freecodecamp) with free courses on Python, SQL, Android, and a wide variety of other technologies.
# - A [podcast](https://podcast.freecodecamp.org/) with technology insights and inspiring stories from developers.
# - A [Developer News](https://www.freecodecamp.org/news) publication, a free, open source, no-ads place to cross-post your blog articles.
#
# > ### [Join our community here](https://www.freecodecamp.org/signin).
#
# ### Reporting Bugs and Issues
# If you think you've found a bug, first read the [how to report a bug](https://www.freecodecamp.org/forum/t/how-to-report-a-bug/19543) article and follow its instructions.
#
# If you're confident it's a new bug and have confirmed that someone else is facing the same issue, go ahead and create a new GitHub issue. Be sure to include as much information as possible so we can reproduce the bug.
#
# ### Reporting Security Issues
#
# If you think you have found a vulnerability, please report responsibly. Don't create GitHub issues for security issues. Instead, please send an email to `security@freecodecamp.org` and we'll look into it immediately.
#
# ### Contributing
#
# > ### [Please follow these steps to contribute.](CONTRIBUTING.md)
#
# ### Platform, Build and Deployment Status
#
# The general platform status for all our applications is available at [`status.freecodecamp.org`](https://status.freecodecamp.org). The build and deployment status for the code is available in [our DevOps Guide](/docs/devops.md).
#
# ### License
#
# Copyright © 2019 freeCodeCamp.org
#
# The content of this repository is bound by the following licenses:
#
# - The computer software is licensed under the [BSD-3-Clause](LICENSE.md) license.
# - The learning resources in the [`/curriculum`](/curriculum) directory including their subdirectories thereon are licensed under the [CC-BY-SA-4.0](/curriculum/LICENSE.md) license.

# %%
for entity in doc.ents:
    print(entity)
    print(entity.label_)
    print(str(spacy.explain(entity.label_)))
    print('\n')
# Out:
# Social Banner](https://s3.amazonaws.com/freecodecamp
# ORG
# Companies, agencies, institutions, etc.
#
#
# first
# ORDINAL
# "first", "second", etc.
#
#
# Friendly](https://img.shields.io
# ORG
# Companies, agencies, institutions, etc.
#
#
# Open Source Helpers](https://www.codetriage.com
# WORK_OF_ART
# Titles of books, songs, etc.
#
#
# Setup Automated](https://img.shields.io
# PERSON
# People, including fictional
#
#
# #
# MONEY
# Monetary values, including unit
#
#
# 501(c)(3
# CARDINAL
# Numerals that do not fall under another type
#
#
# nonprofit](https://donate.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# millions
# CARDINAL
# Numerals that do not fall under another type
#
#
# more than 10,000
# CARDINAL
# Numerals that do not fall under another type
#
#
# first
# ORDINAL
# "first", "second", etc.
#
#
# thousands
# CARDINAL
# Numerals that do not fall under another type
#
#
# #
# MONEY
# Monetary values, including unit
#
#
# Reporting Bugs
# ORG
# Companies, agencies, institutions, etc.
#
#
# Reporting Security
# ORG
# Companies, agencies, institutions, etc.
#
#
# Build
# PERSON
# People, including fictional
#
#
# ###
# MONEY
# Monetary values, including unit
#
#
# Certifications
# ORG
# Companies, agencies, institutions, etc.
#
#
# 5
# CARDINAL
# Numerals that do not fall under another type
#
#
# hundreds
# CARDINAL
# Numerals that do not fall under another type
#
#
# 300 hours
# TIME
# Times smaller than a day
#
#
# 30
# CARDINAL
# Numerals that do not fall under another type
#
#
# CDN](https://cdn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# CodePen
# PERSON
# People, including fictional
#
#
# Glitch - or
# PERSON
# People, including fictional
#
#
# LinkedIn
# PERSON
# People, including fictional
#
#
# one
# CARDINAL
# Numerals that do not fall under another type
#
#
# six
# CARDINAL
# Numerals that do not fall under another type
#
#
# #### 1
# MONEY
# Monetary values, including unit
#
#
# Applied Visual Design](https://learn.freecodecamp.org
# PERSON
# People, including fictional
#
#
# Applied Accessibility](https://learn.freecodecamp.org
# PERSON
# People, including fictional
#
#
# CSS
# ORG
# Companies, agencies, institutions, etc.
#
#
# CSS Grid](https://learn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# br />
#
# ORG
# Companies, agencies, institutions, etc.
#
#
# br />
# ORG
# Companies, agencies, institutions, etc.
#
#
# Tribute Page, Survey Form
# ORG
# Companies, agencies, institutions, etc.
#
#
# Product Landing Page
# ORG
# Companies, agencies, institutions, etc.
#
#
# Technical Documentation Page
# ORG
# Companies, agencies, institutions, etc.
#
#
# #### 2
# MONEY
# Monetary values, including unit
#
#
# JavaScript Algorithms
# ORG
# Companies, agencies, institutions, etc.
#
#
# Data Structures Certification
# ORG
# Companies, agencies, institutions, etc.
#
#
# Regular Expressions](https://learn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# Basic Data Structures](https://learn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# Algorithm Scripting](https://learn.freecodecamp.org
# PERSON
# People, including fictional
#
#
# Object-Oriented Programming](https://learn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# Functional Programming](https://learn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# Algorithm Scripting](https://learn.freecodecamp.org
# PERSON
# People, including fictional
#
#
# br />
#
# ORG
# Companies, agencies, institutions, etc.
#
#
# br />
# ORG
# Companies, agencies, institutions, etc.
#
#
# Palindrome Checker
# PERSON
# People, including fictional
#
#
# Roman Numeral Converter
# ORG
# Companies, agencies, institutions, etc.
#
#
# Caesar's Cipher
# ORG
# Companies, agencies, institutions, etc.
#
#
# #### 3
# MONEY
# Monetary values, including unit
#
#
# Front End Libraries Certification
# ORG
# Companies, agencies, institutions, etc.
#
#
# Sass](https://learn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# React](https://learn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# Redux](https://learn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# React
# ORG
# Companies, agencies, institutions, etc.
#
#
# Redux](https://learn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# br />
#
# ORG
# Companies, agencies, institutions, etc.
#
#
# br />
# ORG
# Companies, agencies, institutions, etc.
#
#
# Random Quote Machine
# ORG
# Companies, agencies, institutions, etc.
#
#
# Markdown Previewer
# ORG
# Companies, agencies, institutions, etc.
#
#
# Drum Machine
# PERSON
# People, including fictional
#
#
# JavaScript
# ORG
# Companies, agencies, institutions, etc.
#
#
# Pomodoro
# NORP
# Nationalities or religious or political groups
#
#
# Clock
# ORG
# Companies, agencies, institutions, etc.
#
#
# #### 4
# MONEY
# Monetary values, including unit
#
#
# Data Visualization Certification
# LAW
# Named documents made into laws.
#
#
# D3](https://learn.freecodecamp.org
# PERSON
# People, including fictional
#
#
# JSON
# ORG
# Companies, agencies, institutions, etc.
#
#
# Ajax](https://learn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# br />
#
# ORG
# Companies, agencies, institutions, etc.
#
#
# br />
# ORG
# Companies, agencies, institutions, etc.
#
#
# Bar Chart
# PERSON
# People, including fictional
#
#
# Heat Map
# ORG
# Companies, agencies, institutions, etc.
#
#
# Choropleth Map
# PERSON
# People, including fictional
#
#
# Treemap Diagram
#
#
# PERSON
# People, including fictional
#
#
# #### 5
# MONEY
# Monetary values, including unit
#
#
# br />
#
# ORG
# Companies, agencies, institutions, etc.
#
#
# br />
# ORG
# Companies, agencies, institutions, etc.
#
#
# Timestamp Microservice
# ORG
# Companies, agencies, institutions, etc.
#
#
# Request Header Parser
# PERSON
# People, including fictional
#
#
# URL Shortener
# ORG
# Companies, agencies, institutions, etc.
#
#
# Exercise Tracker
# PERSON
# People, including fictional
#
#
# File Metadata Microservice
# ORG
# Companies, agencies, institutions, etc.
#
#
# #### 6
# MONEY
# Monetary values, including unit
#
#
# Information Security
# ORG
# Companies, agencies, institutions, etc.
#
#
# HelmetJS](https://learn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# Chai](https://learn.freecodecamp.org
# ORG
# Companies, agencies, institutions, etc.
#
#
# br />
#
# ORG
# Companies, agencies, institutions, etc.
#
#
# br />
# ORG
# Companies, agencies, institutions, etc.
#
#
# Metric-Imperial Converter
# ORG
# Companies, agencies, institutions, etc.
#
#
# Issue Tracker
# PERSON
# People, including fictional
#
#
# Personal Library, Stock Price Checker
# ORG
# Companies, agencies, institutions, etc.
#
#
# Anonymous Message Board
# ORG
# Companies, agencies, institutions, etc.
#
#
# ####
# MONEY
# Monetary values, including unit
#
#
# 6
# CARDINAL
# Numerals that do not fall under another type
#
#
# around 1,800 hours
# TIME
# Times smaller than a day
#
#
# ####
# MONEY
# Monetary values, including unit
#
#
# 3
# CARDINAL
# Numerals that do not fall under another type
#
#
# 2015
# DATE
# Absolute or relative dates or periods
#
#
# ###
# MONEY
# Monetary values, including unit
#
#
# hours
# TIME
# Times smaller than a day
#
#
# Python, SQL
# ORG
# Companies, agencies, institutions, etc.
#
#
# Android
# ORG
# Companies, agencies, institutions, etc.
#
#
# Developer News](https://www.freecodecamp.org
# PERSON
# People, including fictional
#
#
# ###
# MONEY
# Monetary values, including unit
#
#
# ###
# MONEY
# Monetary values, including unit
#
#
# first
# ORDINAL
# "first", "second", etc.
#
#
# GitHub
# ORG
# Companies, agencies, institutions, etc.
#
#
# ###
# MONEY
# Monetary values, including unit
#
#
# GitHub
# ORG
# Companies, agencies, institutions, etc.
#
#
# ###
# MONEY
# Monetary values, including unit
#
#
# ###
# MONEY
# Monetary values, including unit
#
#
# ###
# MONEY
# Monetary values, including unit
#
#
# DevOps Guide](/docs
# PERSON
# People, including fictional
#
#
# ###
# MONEY
# Monetary values, including unit
#
#
# 2019
# DATE
# Absolute or relative dates or periods

# %%
for chunk in doc.noun_chunks:
    print(chunk)
# Out:
# [freeCodeCamp.org
# [Pull
# Requests
# Welcome](https://img.shields.io/badge/PRs
# first-timers
# only Friendly](https://img.shields.io/badge
# timers
# only-friendly-blue.svg)](http://www.firsttimersonly.com/
# [Open Source Helpers](https://www.codetriage.com/freecodecamp/freecodecamp/badges/users.svg)](https://www.codetriage.com/freecodecamp/freecodecamp
# ## freeCodeCamp.org
# a friendly community
# you
# It
# millions
# busy adults transition
# tech
# Our community
# more than 10,000 people
# their first developer job
# Our full-stack web development curriculum
# We
# thousands
# interactive coding challenges
# you
# your skills
# ## Table
# Contents
# * [Certifications](#certifications
# [The Learning Platform](#the-learning-platform
# [Reporting
# Bugs
# Issues](#reporting-bugs
# -issues
# Security
# Issues](#reporting-security-issues
# * [Contributing](#contributing
# ### Certifications
#
# freeCodeCamp.org
# several free developer certifications
# these certifications
# 5 required web app projects
# hundreds
# optional coding challenges
# you
# those projects
# We
# each certification
# a beginning programmer
# 300 hours
# these 30 projects
# the freeCodeCamp.org curriculum
# its own agile user stories
# automated tests
# you
# your project
# you
# all the user stories
# you
# it
# You
# these test suites
# CDN](https://cdn.freecodecamp.org/testable-projects
# you
# these projects
# websites
# CodePen
# Glitch
# your local computer's development environment
# you
# a certification
# you
# it
# You
# it
# your LinkedIn
# your prospective employers
# freelance clients
# that link
# they
# a verified certification
# you
# The one exception
# we
# violations
# our [Academic Honesty Policy](https://www.freecodecamp.org/academic-honesty
# we
# people
# other people's code
# projects
# citation
# we
# what
# all rigorous institutions
# learning
# we
# their certifications
# those people
# our six core certifications
# Responsive Web Design Certification
# [Basic HTML
# HTML5](https://learn.freecodecamp.org
# responsive-web-design
# basic-html
# -html5
# [Basic CSS](https://learn.freecodecamp.org/responsive-web-design/basic-css
# [Applied Visual Design](https://learn.freecodecamp.org/responsive-web-design/applied-visual-design
# [Applied Accessibility](https://learn.freecodecamp.org/responsive-web-design/applied-accessibility
# - [Responsive Web Design Principles](https://learn.freecodecamp.org/responsive-web-design/responsive-web-design-principles
# - [CSS Flexbox](https://learn.freecodecamp.org/responsive-web-design/css-flexbox
# [CSS Grid](https://learn.freecodecamp.org/responsive-web-design/css-grid
# **Projects
# *: Tribute Page
# Survey Form
# Product Landing Page
# Technical Documentation Page
# JavaScript Algorithms and Data Structures Certification
# Basic JavaScript](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures
# [ES6](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/es6
# [Regular Expressions](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/regular-expressions
# [Basic Data Structures](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/basic-data-structures
# - [Algorithm Scripting](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/basic-algorithm-scripting
# [Object-Oriented Programming](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/object-oriented-programming
# - [Functional Programming](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/functional-programming
# [Intermediate Algorithm Scripting](https://learn.freecodecamp.org/javascript-algorithms-and-data-structures/intermediate-algorithm-scripting
# **Projects
# *: Palindrome Checker
# Roman Numeral Converter
# Caesar's Cipher
# Telephone Number Validator
# Front End Libraries Certification
# [Bootstrap](https://learn.freecodecamp.org/front-end-libraries/bootstrap
# - [jQuery](https://learn.freecodecamp.org/front-end-libraries/jquery
# - [Sass](https://learn.freecodecamp.org/front-end-libraries/sass
# - [React](https://learn.freecodecamp.org/front-end-libraries/react
# [React
# Redux](https://learn.freecodecamp.org/front-end-libraries
# react
# **Projects
# **: Random Quote Machine
# Markdown Previewer
# Drum Machine
# JavaScript Calculator
# Pomodoro Clock
# Data Visualization Certification
# [Data Visualization
# D3](https://learn.freecodecamp.org/data-visualization/data-visualization
# -d3
# [JSON APIs
# -ajax
# **Projects
# *: Bar Chart
# Scatterplot Graph
# Heat Map
# Choropleth Map
# Treemap Diagram
# APIs
# Microservices Certification
# Packages
# Npm](https://learn.freecodecamp.org
# apis-and-microservices/managing-packages
# -npm
# [Basic Node
# Express](https://learn.freecodecamp.org
# -microservices
# basic-node
# apis-and-microservices/mongodb
# -mongoose
# **Projects
# Timestamp Microservice
# Request Header Parser
# URL Shortener
# Exercise Tracker
# Information Security and Quality Assurance Certification
# [Information Security
# HelmetJS](https://learn.freecodecamp.org/information-security-and-quality-assurance/information-security
# helmetjs
# [Quality Assurance
# Testing
# Chai](https://learn.freecodecamp.org/information-security-and-quality-assurance/quality-assurance
# -testing
# -chai
# [Advanced Node
# Express](https://learn.freecodecamp.org/information-security-and-quality-assurance
# **Projects
# **: Metric-Imperial Converter
# Issue Tracker
# Personal Library
# Stock Price Checker
# Anonymous Message Board
# #### Full Stack Development Certification
# you
# these certifications
# you
# your freeCodeCamp.org Full Stack Development Certification
# This final distinction
# you
# around 1,800 hours
# a wide range
# web development tools
# #### Legacy Certifications
# We
# 3 legacy certifications
# our 2015 curriculum
# the required projects
# these legacy certifications
# freeCodeCamp.org
# - Legacy Front End Development Certification
# Legacy Data Visualization Certification
# Legacy
# Back End Development Certification
# This code
# [freeCodeCamp.org](https://www.freecodecamp.org
# Our community
# - A
# [forum](https://www.freecodecamp.org/forum
# you
# programming help
# project feedback
# hours
# - A [YouTube channel](https://youtube.com/freecodecamp
# free courses
# Python
# SQL
# Android
# a wide variety
# other technologies
# - A [podcast](https://podcast.freecodecamp.org/
# technology insights
# inspiring stories
# developers
# - A [Developer News](https://www.freecodecamp.org/news) publication
# a free, open source
# no-ads place
# your blog articles
# our community
# /signin
# ### Reporting Bugs
# Issues
# you
# you
# a bug
# a bug](https://www.freecodecamp.org/forum/t/how-to-report-a-bug/19543) article
# its instructions
# you
# it
# a new bug
# someone
# the same issue
# a new GitHub issue
# as much information
# we
# the bug
# ### Reporting Security Issues
# you
# you
# a vulnerability
# GitHub issues
# security issues
# an email
# we
# it
# these steps
# ### Platform
# Build
# Deployment Status
# The general platform status
# all our applications
# [`status.freecodecamp.org`](https://status.freecodecamp.org
# The build and deployment status
# the code
# our DevOps Guide](/docs/devops.md
# ### License
#
# Copyright ©
# freeCodeCamp.org
# The content
# this repository
# the following licenses
# The computer software
# the [BSD-3-Clause](LICENSE.md) license
# The learning resources
# /curriculum`](/curriculum
# their subdirectories thereon
# the [CC-BY-SA-4.0](/curriculum/LICENSE.md) license

# %% [markdown]
# ### Viz with Spacy

# %%
from spacy import displacy

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance':200})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="90f93b09734c4968b1446b1e54e8d728-0" class="displacy" width="255850" height="3337.0" direction="ltr" style="max-width: none; height: 3337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">freeCodeCamp.org</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Social</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">Banner](https://s3.amazonaws.com/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">freecodecamp/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">wide-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">social-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">banner.png)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">
#
# [![</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">Pull</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">Requests</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Welcome](https://img.shields.io/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">badge/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">PRs-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">welcome-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="3250">brightgreen.svg?style</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="3450">=</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3450">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">flat)](http://makeapullrequest.com)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="3850">
# [![</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3850">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="4050">first-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4050">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">timers-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="4450">only</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="4650">Friendly](https://img.shields.io/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="4850">badge/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="5050">first--</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5050">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="5250">timers--</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="5450">only-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="5650">friendly-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3247.0">
#     <tspan class="displacy-word" fill="currentColor" x="5850">blue.svg)](http://www.firsttimersonly.com/)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5850">NOUN</tspan>
# </text

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">![freeCodeCamp.org
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Social Banner](https://s3.amazonaws.com/freecodecamp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /wide-social-banner.png)</br></br>[![Pull Requests Welcome](https://img.shields.io/badge/PRs-welcome-brightgreen.svg?style=flat)](http://makeapullrequest.com)</br>[![
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -timers-only
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Friendly](https://img.shields.io
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /badge/first--timers--only-friendly-blue.svg)](http://www.firsttimersonly.com/)</br>[![
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Open Source Helpers](https://www.codetriage.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# /freecodecamp/freecodecamp/badges/users.svg)](https://www.codetriage.com/freecodecamp/freecodecamp)</br>[![
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Setup Automated](https://img.shields.io
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# /badge/setup-automated-blue?logo=gitpod)](https://gitpod.io/from-referrer/)</br></br>#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     #
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  freeCodeCamp.org's open-source codebase and curriculum</br></br>[freeCodeCamp.org](https://www.freecodecamp.org) is a friendly community where you can learn to code for free. It is run by a [donor-supported
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     501(c)(3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# )
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     nonprofit](https://donate.freecodecamp.org
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) to help
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of busy adults transition into tech. Our community has already helped
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     more than 10,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people get their
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  developer job.</br></br>Our full-stack web development curriculum is completely free and self-paced. We have
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of interactive coding challenges to help you expand your skills.</br></br>#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     #
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  Table of Contents</br></br>* [Certifications](#certifications)</br>* [The Learning Platform](#the-learning-platform)</br>* [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Reporting Bugs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Issues](#reporting-bugs-and-issues)</br>* [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Reporting Security
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Issues](#reporting-security-issues)</br>* [Contributing](#contributing)</br>* [Platform,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Build
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and Deployment Status](#platform-build-and-deployment-status)</br>* [License](#license)</br></br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em;

# %%
# inside .py script

displacy.serve(doc, style='dep')
# Out:
# /usr/local/anaconda3/lib/python3.7/runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="14d04bb7365d4787afaa0ce32680f599-0" class="displacy" width="223875" height="2937.0" direction="ltr" style="max-width: none; height: 2937.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">freeCodeCamp.org</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Social</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Banner](https://s3.amazonaws.com/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">freecodecamp/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">wide-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">social-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">banner.png)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">
#
# [![</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Pull</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Requests</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Welcome](https://img.shields.io/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">badge/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">PRs-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">welcome-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">brightgreen.svg?style</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">=</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">flat)](http://makeapullrequest.com)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">
# [![</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">first-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">timers-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">only</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Friendly](https://img.shields.io/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">badge/</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">first--</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">timers--</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">only-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2847.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">friendly-</tspan>
#     <tspan class="displacy-tag" d
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# ## Stemming

# %% [markdown]
# ## Tokenize

# %%
doc2 = nlp(u"Tesla isn't    looking for startups anymore")

# %%
for token in doc2:
    print(token.text, token.pos_, token.dep_)
# Out:
# Tesla PROPN nsubj
# is VERB ROOT
# n't ADV neg
#     SPACE
# looking VERB acomp
# for ADP prep
# startups NOUN pobj
# anymore ADV advmod

# %%
doc2[0]
# Out:
# Tesla

# %%
doc2[0].pos_
# Out:
# 'PROPN'

# %%
doc2[0].dep_
# Out:
# 'nsubj'

# %%
# Noun Proper Singular

doc2[0].tag_
# Out:
# 'NNP'

# %%
df.head()
# Out:
#      language                                    readme_contents  \
# 0  JavaScript  ![freeCodeCamp.org Social Banner](https://s3.a...
# 1        Rust  [996.ICU](https://996.icu/#/en_US)\n=======\n*...
# 2  JavaScript  <p align="center"><a href="https://vuejs.org" ...
# 3  JavaScript  # [React](https://reactjs.org/) &middot; [![Gi...
# 4         C++  <div align="center">\n  <img src="https://www....
#
#                         repo
# 0  freeCodeCamp/freeCodeCamp
# 1             996icu/996.ICU
# 2                  vuejs/vue
# 3             facebook/react
# 4      tensorflow/tensorflow

# %%
df = prepare.prep_articles(df)

# %%
df = df[['language', 'cleaned']]

# %%
df.head()
# Out:
#      language                                            cleaned
# 0  JavaScript  freecodecamp social amazonaws freecodecamp wid...
# 1        Rust  please note exists official account app mercha...
# 2  JavaScript  align center href vuejs target blank rel noope...
# 3  JavaScript  react reactjs middot github license shield bad...
# 4         C++  div align center src tensorflow image logo soc...

# %%
df = df.assign(stemmed = df.original.apply(tokenize).apply(stem))

df = df.assign(lemmatized = df.original.apply(tokenize).apply(lemmatize))

# cleaned == lemmatized without stopwords
# cleaned will be our feature

df = df.assign(cleaned = df.lemmatized.apply(remove_stopwords))

df.head()
# Out:
#      language                                           original  \
# 0  JavaScript  freecodecamp org social banner  https     amaz...
# 1        Rust  icu  https       icu                please not...
# 2  JavaScript  align  center    href  https   vuejs org  targ...
# 3  JavaScript  react  https   reactjs org    middot     githu...
# 4         C++  div align  center      img src  https   www te...
#
#                                              stemmed  \
# 0  freecodecamp org social banner http amazonaw c...
# 1  icu http icu pleas note that there exist other...
# 2  align center href http vuej org target blank r...
# 3  react http reactj org middot github licens htt...
# 4  div align center img src http www tensorflow o...
#
#                                           lemmatized  \
# 0  freecodecamp org social banner http amazonaws ...
# 1  icu http icu please note that there exists oth...
# 2  align center href http vuejs org target blank ...
# 3  react http reactjs org middot github license h...
# 4  div align center img src http www tensorflow o...
#
#                                              cleaned
# 0  freecodecamp org social banner http amazonaws ...
# 1  icu http icu please note exists official accou...
# 2  align center href http vuejs org target blank ...
# 3  react http reactjs org middot github license h...
# 4  div align center img src http www tensorflow o...

# %%
df = df[]

# %%
df.readme_contents[0]
# Out:
# "freecodecamp org social banner https s3 amazonaws com freecodecamp wide social banner png pull requests welcome https img shields io badge prs welcome brightgreen svg style flat http makeapullrequest com first timers only friendly https img shields io badge first timers only friendly blue svg http www firsttimersonly com open source helpers https www codetriage com freecodecamp freecodecamp badges users svg https www codetriage com freecodecamp freecodecamp setup automated https img shields io badge setup automated blue logo gitpod https gitpod io from referrer freecodecamp org ' s open source codebase and curriculum freecodecamp org https www freecodecamp org is a friendly community where you can learn to code for free it is run by a donor supported 501 c 3 nonprofit https donate freecodecamp org to help millions of busy adults transition into tech our community has already helped more than 10 000 people get their first developer job our full stack web development curriculum is completely free and self paced we have thousands of interactive coding challenges to help you expand your skills table of contents certifications certifications the learning platform the learning platform reporting bugs and issues reporting bugs and issues reporting security issues reporting security issues contributing contributing platform build and deployment status platform build and deployment status license license certifications freecodecamp org offers several free developer certifications each of these certifications involves building 5 required web app projects along with hundreds of optional coding challenges to help you prepare for those projects we estimate that each certification will take a beginning programmer around 300 hours to earn each of these 30 projects in the freecodecamp org curriculum has its own agile user stories and automated tests these help you build up your project incrementally and ensure you ' ve fulfilled all the user stories before you submit it you can pull in these test suites through freecodecamp ' s cdn https cdn freecodecamp org testable projects fcc v1 bundle js this means you can build these projects on websites like codepen and glitch or even on your local computer ' s development environment once youve earned a certification you will always have it you will always be able to link to it from your linkedin or resume and when your prospective employers or freelance clients click that link theyll see a verified certification specific to you the one exception to this is if we discover violations of our academic honesty policy https www freecodecamp org academic honesty when we catch people unambiguously plagiarizing submitting other people ' s code or projects as their own without citation we do what all rigorous institutions of learning should do we revoke their certifications and ban those people here are our six core certifications 1 responsive web design certification basic html and html5 https learn freecodecamp org responsive web design basic html and html5 basic css https learn freecodecamp org responsive web design basic css applied visual design https learn freecodecamp org responsive web design applied visual design applied accessibility https learn freecodecamp org responsive web design applied accessibility responsive web design principles https learn freecodecamp org responsive web design responsive web design principles css flexbox https learn freecodecamp org responsive web design css flexbox css grid https learn freecodecamp org responsive web design css grid br br projects tribute page survey form product landing page technical documentation page personal portfolio webpage 2 javascript algorithms and data structures certification basic javascript https learn freecodecamp org javascript algorithms and data structures basic javascript es6 https learn freecodecamp org javascript algorithms and data structures es6 regular expressions https learn freecodecamp org javascript algorithms and data structu ...

# %%
df = df.rename(columns={'readme_contents': 'original'})

# %%
df.head()
# Out:
#      language                                           original  \
# 0  JavaScript  freecodecamp org social banner https s3 amazon...
# 1        Rust  996 icu https 996 icu en us please note that t...
# 2  JavaScript  p align center a href https vuejs org target b...
# 3  JavaScript  react https reactjs org middot github license ...
# 4         C++  div align center img src https www tensorflow ...
#
#                         repo
# 0  freeCodeCamp/freeCodeCamp
# 1             996icu/996.ICU
# 2                  vuejs/vue
# 3             facebook/react
# 4      tensorflow/tensorflow

# %%
#soup = BeautifulSoup(response.content)

# %%
#soup.title
# Out:
# <title>GitHub - rbenv/rbenv: Groom your app’s Ruby environment</title>

# %%
# get body of README
# body = soup.find('article', class_='markdown-body').get_text()
# body
# Out:
# 'Groom your app’s Ruby environment with rbenv.\nUse rbenv to pick a Ruby version for your application and guarantee\nthat your development environment matches production. Put rbenv to work\nwith Bundler for painless Ruby upgrades and\nbulletproof deployments.\nPowerful in development. Specify your app\'s Ruby version once,\nin a single file. Keep all your teammates on the same page. No\nheadaches running apps on different versions of Ruby. Just Works™\nfrom the command line and with app servers like Pow.\nOverride the Ruby version anytime: just set an environment variable.\nRock-solid in production. Your application\'s executables are its\ninterface with ops. With rbenv and Bundler\nbinstubs\nyou\'ll never again need to cd in a cron job or Chef recipe to\nensure you\'ve selected the right runtime. The Ruby version\ndependency lives in one place—your app—so upgrades and rollbacks are\natomic, even when you switch versions.\nOne thing well. rbenv is concerned solely with switching Ruby\nversions. It\'s simple and predictable. A rich plugin ecosystem lets\nyou tailor it to suit your needs. Compile your own Ruby versions, or\nuse the ruby-build\nplugin to automate the process. Specify per-application environment\nvariables with rbenv-vars.\nSee more plugins on the\nwiki.\nWhy choose rbenv over\nRVM?\nTable of Contents\n\nHow It Works\n\nUnderstanding PATH\nUnderstanding Shims\nChoosing the Ruby Version\nLocating the Ruby Installation\n\n\nInstallation\n\nHomebrew on macOS\n\nUpgrading with Homebrew\n\n\nBasic GitHub Checkout\n\nUpgrading with Git\nUpdating the list of available Ruby versions\n\n\nHow rbenv hooks into your shell\nInstalling Ruby versions\n\nInstalling Ruby gems\n\n\nUninstalling Ruby versions\nUninstalling rbenv\n\n\nCommand Reference\n\nrbenv local\nrbenv global\nrbenv shell\nrbenv versions\nrbenv version\nrbenv rehash\nrbenv which\nrbenv whence\n\n\nEnvironment variables\nDevelopment\n\nHow It Works\nAt a high level, rbenv intercepts Ruby commands using shim\nexecutables injected into your PATH, determines which Ruby version\nhas been specified by your application, and passes your commands along\nto the correct Ruby installation.\nUnderstanding PATH\nWhen you run a command like ruby or rake, your operating system\nsearches through a list of directories to find an executable file with\nthat name. This list of directories lives in an environment variable\ncalled PATH, with each directory in the list separated by a colon:\n/usr/local/bin:/usr/bin:/bin\n\nDirectories in PATH are searched from left to right, so a matching\nexecutable in a directory at the beginning of the list takes\nprecedence over another one at the end. In this example, the\n/usr/local/bin directory will be searched first, then /usr/bin,\nthen /bin.\nUnderstanding Shims\nrbenv works by inserting a directory of shims at the front of your\nPATH:\n~/.rbenv/shims:/usr/local/bin:/usr/bin:/bin\n\nThrough a process called rehashing, rbenv maintains shims in that\ndirectory to match every Ruby command across every installed version\nof Ruby—irb, gem, rake, rails, ruby, and so on.\nShims are lightweight executables that simply pass your command along\nto rbenv. So with rbenv installed, when you run, say, rake, your\noperating system will do the following:\n\nSearch your PATH for an executable file named rake\nFind the rbenv shim named rake at the beginning of your PATH\nRun the shim named rake, which in turn passes the command along to\nrbenv\n\nChoosing the Ruby Version\nWhen you execute a shim, rbenv determines which Ruby version to use by\nreading it from the following sources, in this order:\n\n\nThe RBENV_VERSION environment variable, if specified. You can use\nthe rbenv shell command to set this environment\nvariable in your current shell session.\n\n\nThe first .ruby-version file found by searching the directory of the\nscript you are executing and each of its parent directories until reaching\nthe root of your filesystem.\n\n\nThe first .ruby-versio ...

# %%
# find README language

# language = soup.find('span', class_= 'lang').get_text()
# language
